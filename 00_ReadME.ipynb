# %% [markdown]
# # Python notebook descriptions
# ## - The following set of notebooks treat the data and produce the final outputs for the Figures in the paper.
# ## - This notebook summarizes the data produced with each treatment python notebook

# %% [markdown]
# # Download the following datasets from ()
# > Dataset_11 <br> Dataset_21 <br> Dataset_31 <br> Dataset_41

# %% [markdown]
# # Run the next cells to make the folder structure for the datasets produced with each python sheet

# %%
mkdir dataset_12

# %%
mkdir dataset_22

# %%
mkdir dataset_23

# %%
mkdir dataset_24

# %%
mkdir dataset_25

# %%
mkdir dataset_26

# %%
mkdir dataset_27

# %%
mkdir dataset_28

# %%
mkdir dataset_29

# %%
mkdir dataset_32

# %%
mkdir dataset_33

# %%
mkdir dataset_42

# %%
mkdir dataset_43

# %% [markdown]
# # Dataset Descriptions
# ## Below are descriptions of the datasets referred to in each Jupyter notebook. Datasets ending in the number '1' are raw data that must be downloaded via the instructions above. All other datasets are those that are generated by following the steps in the Jupyter notebooks and placed in the appropriate folders (created above).

# %% [markdown]
# ## Dataset_11 (SEPARATE .dat!!)
# > 15092501.dat <br>
# - 'P-020' = scan #s 123, 129, 135 <br>
# - 'P-415' = scan #s 141, 147, 153 <br>
# - 'P-600' = scan #s 159, 165, 171 <br>
# - 'P-750' = scan #s 179, 185, 191 <br> <br> *filename consistent with that at ESRF*
#
# ### @WOUT: is there a way to separate these out into its own raw .dat file?

# %% [markdown]
# ## Dataset_12
# > 2015_avg_P020.txt <br> 2015_avg_P415.txt <br> 2015_avg_P600.txt <br> 2015_avg_P750.txt

# %% [markdown]
# ## Dataset_21
# > 20Vpow_1.h5 <br> 415pow_1.hf <br> 600Vpow_1.h5 <br> 750Vpow_1.h5 <br> 20VoilL4.h5 <br> 750VL4.h5 <br> <br> *filenames consistent with those at ESRF*

# %% [markdown]
# ## Dataset_22
# > H020_norm.hdf <br> H415_norm.hdf <br> H600_norm.hdf <br> H750_norm.hdf <br> H020oilL4_norm.hdf <br> H750oilL4_norm.hdf

# %% [markdown]
# ## Dataset_x
# > H020_energy_1.csv

# %% [markdown]
# ## Dataset_23
# > mean_value_H020_norm_'date'.png <br> mean_value_H415_norm_'date'.png <br> mean_value_600Vpow_1_'date'.png <br> mean_value_H750_norm_'date'.png <br> mean_value_H020oilL4_norm_'date'.png <br> mean_value_H750oilL4_norm_'date'.png

# %% [markdown]
# ## Dataset_24
# > mask_mean_value_H020_norm_'date'.png <br> mask_mean_value_H415_norm_'date'.png <br> mask_mean_value_600Vpow_1_'date'.png <br> mask_mean_value_H750_norm_'date'.png <br> mask_mean_value_H020oilL4_norm_'date'.png <br> mask_mean_value_H750oilL4_norm_'date'.png

# %% [markdown]
# ## Dataset_25
# > H020_norm_wanted_particles_average_'date'.txt <br> H415_norm_wanted_particles_average_'date'.txt <br> H600_norm_wanted_particles_average_'date'.txt <br> H750_norm_wanted_particles_average_'date'.txt <br> H020oilL4_norm_wanted_particles_average_'date'.txt <br> H750oilL4_norm_wanted_particles_average_'date'.txt <br>

# %% [markdown]
# ## Dataset_26
# > NMF_H750fit_3components_'date'_0.svg

# %% [markdown]
# ## Dataset_27
# > NMF_H750fit_com_of_3_'date'_0.png (dpi = 600)

# %% [markdown]
# ## Dataset_28
# with tick labels for reference
# > H020_norm_diff31_of_3_'date'_0.svg <br>
# H415_norm_diff31_of_3_'date'_0.svg <br>
# H650_norm_diff31_of_3_'date'_0.svg <br>
# H750_norm_diff31_of_3_'date'_0.svg <br>
# H020oilL4_norm_diff31_of_3_'date'_0.svg <br>
# H750oilL4_norm_diff31_of_3_'date'_0.svg
#
# without tick labels for figure presentation
# > H020_normnotix_diff31_of_3_'date'_0.svg <br>
# H415_normnotix_diff31_of_3_'date'_0.svg <br>
# H650_normnotix_diff31_of_3_'date'_0.svg <br>
# H750_normnotix_diff31_of_3_'date'_0.svg <br>
# H020oilL4_normnotix_diff31_of_3_'date'_0.svg <br>
# H750oilL4_normnotix_diff31_of_3_'date'_0.svg

# %% [markdown]
# ## Dataset_29
# consequentive spectra across two particles
# > spec_H020_norm_diff31_of_3_'date'_0.svg <br>
# spec_H415_norm_diff31_of_3_'date'_0.svg <br>
# spec_H650_norm_diff31_of_3_'date'_0.svg <br>
# spec_H750_norm_diff31_of_3_'date'_0.svg (1st & 2nd)<br>
# spec_H750_norm_diff31_of_3_'date'_1.svg (3rd & 4th)<br>
#
# locations of particles on full image with cursors showing location of spectra
# > H020_norm_20190524_cursors_um_0.svg <br>
# H415_norm_20190524_cursors_um_0.svg <br>
# H600_norm_20190524_cursors_um_0.svg <br>
# H750_norm_20190524_cursors_um_0.svg (1st & 2nd)<br>
# H750_norm_20190524_cursors_um_1.svg (3rd & 4th)<br>
#
# zoom of particles with cursors showing location of spectra (with tick labels for reference)
# > H020_norm_1st_'date'_cursors_um_0.svg <br>
# H020_norm_2nd_'date'_cursors_um_0.svg <br><br>
# H415_norm_1st_'date'_cursors_um_0.svg <br>
# H415_norm_2nd_'date'_cursors_um_0.svg <br><br>
# H600_norm_1st_'date'_cursors_um_0.svg <br>
# H600_norm_2nd_'date'_cursors_um_0.svg <br><br>
# H750_norm_1st_'date'_cursors_um_0.svg <br>
# H750_norm_2nd_'date'_cursors_um_0.svg <br>
# H750_norm_3rd_'date'_cursors_um_0.svg <br>
# H750_norm_4th_'date'_cursors_um_0.svg <br>
#
# zoom of particles with cursors showing location of spectra (without tick labels for figure presentation)
# > H020_norm_notix_1st_'date'_cursors_um_0.svg <br>
# H020_norm_notix_2nd_'date'_cursors_um_0.svg <br><br>
# H415_norm_notix_1st_'date'_cursors_um_0.svg <br>
# H415_norm_notix_2nd_'date'_cursors_um_0.svg <br><br>
# H600_norm_notix_1st_'date'_cursors_um_0.svg <br>
# H600_norm_notix_2nd_'date'_cursors_um_0.svg <br><br>
# H750_norm_notix_1st_'date'_cursors_um_0.svg <br>
# H750_norm_notix_2nd_'date'_cursors_um_0.svg <br>
# H750_norm_notix_3rd_'date'_cursors_um_0.svg <br>
# H750_norm_notix_4th_'date'_cursors_um_0.svg <br>

# %% [markdown]
# ## Dataset_31 (SEPARATE .h5!!)
# > allfiles_hg94.h5 <br>
# - 'MH0170_5_att' = scan #s 133 - 150 <br>
# *note:* mislabeled in .h5 as 'SKA2845_2_att' <br>
# - 'SKA2102_8_att' = scan #s 190 - 222 <br>
# *note:* mislabeled in .h5 as 'SKA2845_2_att'

# %% [markdown]
# ## Dataset_32
# > c_2017_MH0170_5_133_150.dat <br> c_2017_SKA2102_8_190_222.dat

# %% [markdown]
# ## Dataset_33
# > c_2017_MH0170_5_vals_133to137_'date'_1.csv <br>
# c_2017_MH0170_5_vals_138to140_'date'_1.csv <br>
# c_2017_MH0170_5_vals_141to142_'date'_1.csv <br>
# c_2017_MH0170_5_vals_143to145_'date'_1.csv <br>
# c_2017_MH0170_5_vals_146to148_'date'_1.csv <br>
# c_2017_MH0170_5_vals_149to150_'date'_1.csv <br> <br>
# c_2017_SKA2102_8_vals_190to191_'date'_1.csv <br>
# c_2017_SKA2102_8_vals_192to193_'date'_1.csv <br>
# c_2017_SKA2102_8_vals_194to195_'date'_1.csv <br>
# c_2017_SKA2102_8_vals_196to198_'date'_1.csv <br>
# c_2017_SKA2102_8_vals_199to202_'date'_1.csv <br>
# c_2017_SKA2102_8_vals_203only_'date'_1.csv <br>
# c_2017_SKA2102_8_vals_204to207_'date'_1.csv <br>
# c_2017_SKA2102_8_vals_208to212_'date'_1.csv <br>
# c_2017_SKA2102_8_vals_213to215_'date'_1.csv <br>
# c_2017_SKA2102_8_vals_216to217_'date'_1.csv <br>
# c_2017_SKA2102_8_vals_218to219_'date'_1.csv <br>
# c_2017_SKA2102_8_vals_220to222_'date'_1.csv

# %% [markdown]
# ## Dataset_41 (SEPARATE .h5!!)
# > allfiles_hg139_2.h5 <br>
# - 'MH0264X07b_att' = scan #s 003 - 060 <br>
# - 'S18500_att' = scan #s 002 - 051 <br>
# - 'S18506_att' = scan #s 002 - 059 <br>

# %% [markdown]
# ## Dataset_42
# > c_2018_MH0264X07b_003_060.dat <br> c_2018_S18500_002_051.dat <br> c_2018_S18506_002_059.dat

# %% [markdown]
# ## Dataset_43
# > c_2018_MH0264X07b_vals_12to18_'date'_1.csv <br>
# c_2018_MH0264X07b_vals_19to22_'date'_1.csv <br>
# c_2018_MH0264X07b_vals_23to25_'date'_1.csv <br>
# c_2018_MH0264X07b_vals_26to31_'date'_1.csv <br>
# c_2018_MH0264X07b_vals_32to33_'date'_1.csv <br>
# c_2018_MH0264X07b_vals_34to37_'date'_1.csv <br>
# c_2018_MH0264X07b_vals_38to39_'date'_1.csv <br>
# c_2018_MH0264X07b_vals_3to11skip8_'date'_1.csv <br>
# c_2018_MH0264X07b_vals_40only_'date'_1.csv <br>
# c_2018_MH0264X07b_vals_41only_'date'_1.csv <br>
# c_2018_MH0264X07b_vals_42to45_'date'_1.csv <br>
# c_2018_MH0264X07b_vals_46to49_'date'_1.csv <br>
# c_2018_MH0264X07b_vals_50to54_'date'_1.csv <br>
# c_2018_MH0264X07b_vals_55to57_'date'_1.csv <br><br>
# c_2018_S18500_vals_11to13_'date'_1.csv <br>
# c_2018_S18500_vals_14to16_'date'_1.csv <br>
# c_2018_S18500_vals_17to24_'date'_1.csv <br>
# c_2018_S18500_vals_25to27_'date'_1.csv <br>
# c_2018_S18500_vals_28to31_'date'_1.csv <br>
# c_2018_S18500_vals_2to3_'date'_1.csv <br>
# c_2018_S18500_vals_32to33_'date'_1.csv <br>
# c_2018_S18500_vals_34to39_'date'_1.csv <br>
# c_2018_S18500_vals_40to41_'date'_1.csv <br>
# c_2018_S18500_vals_42to43and51_'date'_1.csv <br>
# c_2018_S18500_vals_44to45_'date'_1.csv <br>
# c_2018_S18500_vals_46only_'date'_1.csv <br>
# c_2018_S18500_vals_48to49_'date'_1.csv <br>
# c_2018_S18500_vals_4to10_'date'_1.csv <br>
# c_2018_S18500_vals_50only_'date'_1.csv <br>
# c_2018_S18506_vals_16to22_'date'_1.csv <br><br>
# c_2018_S18506_vals_23to25_'date'_1.csv <br>
# c_2018_S18506_vals_26to30_'date'_1.csv <br>
# c_2018_S18506_vals_2to7_'date'_1.csv <br>
# c_2018_S18506_vals_31to34_'date'_1.csv <br>
# c_2018_S18506_vals_35to38_'date'_1.csv <br>
# c_2018_S18506_vals_39to47_'date'_1.csv <br>
# c_2018_S18506_vals_48to54_'date'_1.csv <br>
# c_2018_S18506_vals_55to59_'date'_1.csv <br>
# c_2018_S18506_vals_8to15_'date'_1.csv <br>

# %% [markdown]
# ## Dataset_RAD NEED!!!!!!!!!!
# > !!c_2017_MH0169_vals_054_058_'date'_1.csv

# %% [markdown]
# ## Dataset_XRFmaps NEED!!!
# need!!

# %% [markdown]
# # Specifics for Figures that require Jupyter workup

# %% [markdown]
# ## Figure 1
# ### Input
# [dataset12] ()
# > 2015_avg_P020.txt <br> 2015_avg_P415.txt <br> 2015_avg_P600.txt <br> 2015_avg_P750.txt
#
# [dataset25] ()
# > H020_norm_wanted_particles_average_'date'.txt <br> H415_norm_wanted_particles_average_'date'.txt <br> H600_norm_wanted_particles_average_'date'.txt <br> H750_norm_wanted_particles_average_'date'.txt <br> H020oilL4_norm_wanted_particles_average_'date'.txt <br> H750oilL4_norm_wanted_particles_average_'date'.txt <br>
#
# ### Output (Input for Inkscape)
# [Figure_1]
# > Figure1_date_0.svg <br>
# Figure1_date_inset_0.svg

# %% [markdown]
# ## Figure 4
# ### Input
# [dataset33] ()
# > c_2017_MH0170_5_vals_133to137_'date'_1.csv <br> c_2017_SKA2102_8_vals_194to195_'date'_1.csv
#
# [dataset43] ()
# > c_2018_MH0264X07b_vals_38to39_'date'_1.csv <br> c_2018_S18500_vals_34to39_'date'_1.csv <br> c_2018_S18506_vals_16to22_'date'_1.csv
#
# ### Output (Input for Inkscape)
# > Figure4_data_0.svg

# %% [markdown]
# ## Figure 5
# ### Input
# [dataset43]
# > c_2018_S18500_vals_002to003_1.csv <br>
# c_2018_S18500_vals_004to010_1.csv <br>
# c_2018_S18500_vals_011to013_1.csv <br>
# c_2018_S18500_vals_014to016_1.csv <br>
# c_2018_S18500_vals_017to024_1.csv <br>
# c_2018_S18500_vals_025to027_1.csv <br>
# c_2018_S18500_vals_028to031_1.csv <br>
# c_2018_S18500_vals_032_033_1.csv <br>
# c_2018_S18500_vals_034to039_1.csv <br>
# c_2018_S18500_vals_040_041_1.csv <br>
# c_2018_S18500_vals_042_043_051_1.csv <br>
# c_2018_S18500_vals_044_045_1.csv <br>
# c_2018_S18500_vals_046only_1.csv <br>
# c_2018_S18500_vals_046to047_1.csv <br>
# c_2018_S18500_vals_048to049_1.csv <br>
# c_2018_S18500_vals_050_1.csv <br> <br>
#
# ### Output (Input for Inkscape)
# > Figure5_date_S18500_0.svg

# %% [markdown]
# ## Figure SI-5 NEED
# [datasetRAD]
# !!c_2017_MH0169_vals_054_058_'date'_1.csv

# %% [markdown]
# ## Figure SI-7
# ### Input
# [dataset33] ()
# > c_2017_MH0170_5_vals_133to137_1.csv <br>
# c_2017_MH0170_5_vals_138to140_1.csv <br>
# c_2017_MH0170_5_vals_141to142_1.csv <br>
# c_2017_MH0170_5_vals_143to145_1.csv <br>
# c_2017_MH0170_5_vals_146to148_1.csv <br>
# c_2017_MH0170_5_vals_149to150_1.csv <br> <br>
# c_2017_SKA2102_8_vals_190to191_1.csv <br>
# c_2017_SKA2102_8_vals_192to193_1.csv <br>
# c_2017_SKA2102_8_vals_194to195_1.csv <br>
# c_2017_SKA2102_8_vals_196to198_1.csv <br>
# c_2017_SKA2102_8_vals_199to202_1.csv <br>
# c_2017_SKA2102_8_vals_203only_1.csv <br>
# c_2017_SKA2102_8_vals_204to207_1.csv <br>
# c_2017_SKA2102_8_vals_208to212_1.csv <br>
# c_2017_SKA2102_8_vals_213to215_1.csv <br>
# c_2017_SKA2102_8_vals_216to217_1.csv <br>
# c_2017_SKA2102_8_vals_218to219_1.csv <br>
# c_2017_SKA2102_8_vals_220to222_1.csv
#
# [dataset43] ()
# > c_2018_MH0264X07b_vals_003to011not008_1.csv <br>
# c_2018_MH0264X07b_vals_012to018_1.csv <br>
# c_2018_MH0264X07b_vals_019to022_1.csv <br>
# c_2018_MH0264X07b_vals_023to025_1.csv <br>
# c_2018_MH0264X07b_vals_026to031_1.csv <br>
# c_2018_MH0264X07b_vals_032to033_1.csv <br>
# c_2018_MH0264X07b_vals_034to037_1.csv <br>
# c_2018_MH0264X07b_vals_038to039_1.csv <br>
# c_2018_MH0264X07b_vals_040only_1.csv <br>
# c_2018_MH0264X07b_vals_041only_1.csv <br>
# c_2018_MH0264X07b_vals_042to045_1.csv <br>
# c_2018_MH0264X07b_vals_046to049_1.csv <br>
# c_2018_MH0264X07b_vals_050to054_1.csv <br>
# c_2018_MH0264X07b_vals_055to057_1.csv <br> <br>
# c_2018_S18506_vals_002to007_1.csv <br>
# c_2018_S18506_vals_008to015_1.csv <br>
# c_2018_S18506_vals_016to022_1.csv <br>
# c_2018_S18506_vals_023to025_1.csv <br>
# c_2018_S18506_vals_026to030_1.csv <br>
# c_2018_S18506_vals_031to034_1.csv <br>
# c_2018_S18506_vals_035to038_1.csv <br>
# c_2018_S18506_vals_039to047_1.csv <br>
# c_2018_S18506_vals_048to054_1.csv <br>
# c_2018_S18506_vals_055to059_1.csv
#
# ### Output
# > FigureSI7_date_MH0170_0.svg <br>
# FigureSI7_date_SKA2102_0.svg <br>
# FigureSI7_date_MH0284X07b_0.svg <br>
# FigureSI7_date_S18506_0.svg <br>

# %% [markdown]
# # Specifics for Figures that only require arranging in Inkscape

# %% [markdown]
# ## Figure 2
# ### Input
# [dataset26] ()
# > NMF_H750fit_3components_'date'_0.svg
#
# [dataset27] ()
# > NMF_H750fit_com_of_3_'date'_0.png (dpi = 600)
#
# [dataset28] ()
# without tick labels for figure presentation
# > H020_normnotix_diff31_of_3_'date'_0.svg <br>
# H415_normnotix_diff31_of_3_'date'_0.svg <br>
# H650_normnotix_diff31_of_3_'date'_0.svg <br>
# H750_normnotix_diff31_of_3_'date'_0.svg <br>
#
# [dataset29] ()
# consequentive spectra across two particles
# > spec_H750_norm_diff31_of_3_'date'_0.svg (1st & 2nd)
#
# zoom of particles with cursors showing location of spectra (without tick labels for figure presentation)
# > H750_norm_notix_1st_'date'_cursors_um_0.svg <br>
# H750_norm_notix_2nd_'date'_cursors_um_0.svg <br>

# %% [markdown]
# ## Figure 3 UPDATE
# ### Input
# > painting images

# %% [markdown]
# ## Figure SI-1
# ### Input
# > TEM images

# %% [markdown]
# ## Figure SI-2
# ### Input
# > lapis lazuli and lazurite powder images

# %% [markdown]
# ## Figure SI-3
# [dataset29] ()
# consequentive spectra across two particles
# > spec_H020_norm_diff31_of_3_'date'_0.svg <br>
# spec_H415_norm_diff31_of_3_'date'_0.svg <br>
# spec_H650_norm_diff31_of_3_'date'_0.svg <br>
# spec_H750_norm_diff31_of_3_'date'_1.svg (3rd & 4th)<br>
#
# zoom of particles with cursors showing location of spectra (without tick labels for figure presentation)
# > H020_norm_notix_1st_'date'_cursors_um_0.svg <br>
# H020_norm_notix_2nd_'date'_cursors_um_0.svg <br><br>
# H415_norm_notix_1st_'date'_cursors_um_0.svg <br>
# H415_norm_notix_2nd_'date'_cursors_um_0.svg <br><br>
# H600_norm_notix_1st_'date'_cursors_um_0.svg <br>
# H600_norm_notix_2nd_'date'_cursors_um_0.svg <br><br>
# H750_norm_notix_3rd_'date'_cursors_um_0.svg <br>
# H750_norm_notix_4th_'date'_cursors_um_0.svg <br>

# %% [markdown]
# ## Figure SI-4
# [dataset28] ()
# without tick labels for figure presentation
# > H020_normnotix_diff31_of_3_'date'_0.svg <br>
# H415_normnotix_diff31_of_3_'date'_0.svg <br>
# H650_normnotix_diff31_of_3_'date'_0.svg <br>
# H750_normnotix_diff31_of_3_'date'_0.svg <br>
# H020oilL4_normnotix_diff31_of_3_'date'_0.svg <br>
# H750oilL4_normnotix_diff31_of_3_'date'_0.svg

# %% [markdown]
# ## Figure SI-6 NEED
# XRF maps
# crossection images
