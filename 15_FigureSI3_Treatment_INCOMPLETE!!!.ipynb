# %% [markdown]
# # **Figure SI3 Treatment**
#
# ### Program:
# [Jupyter notebook >=5.5, Python >=3.4]
#
# ### Input:
# - normalized individual spectra from 2017 samples, type = .txt, [datasetrad] ()
#
# ### Steps:
# - follow script below
#
# ### Output:
#
# #### Treatment Va:
# - Figure SI3, type = .svg or .pdf, [FigureSI3] ()
# > FigureSI3_date_1 <br>
#
# ### Notes:
# - all comments are made with '##'
# - aspects that can be changed depending on the sample, etc. are with '#'
#
# ### Additional Notes:
# - Figure layout and extra labels were accomplished in [Inkscape 0.92.4] (https://inkscape.org/)

# %%
##UPDATE WITH SAMPLE MH0169_1a after spectrocrunch

# %%
# %pylab inline
import imageio
import numpy as np
import pandas as pd
import os
from glob import glob
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
##standards for figures
SMALL_SIZE = 24
MEDIUM_SIZE = 24
BIGGER_SIZE = 24

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
date = datetime.datetime.now().strftime("%Y%m%d")
try:
    os.mkdir('Figure_SI3')
except OSError:
    pass

# %%
files = sorted(glob(os.path.join('dataset_rad', '*.txt')
files
# Out:
# ['rad_dam_data.txt']

# %%
##enter the figure name here that will be the filename for the image of the figure output below
FIG_name = 'FigureSIrad_{}_'.format(date)  ## underscore at end to allow indexing when saving below
FIG_name
# Out:
# 'FigureSIrad_20190410_'

# %%
##read in  tx files tab-delimited)
all_data = pd.read_csv(files[0], delimiter='\t',header = [0], index_col = [0])
all_data.index.name = 'energy_cor'

#all_data
all_data_p = all_data[['20N_norm_scan75','20N_norm_scan76','20N_norm_scan77',
                       '20N_norm_scan79','20N_norm_scan81','20N_norm_scan82']]
all_data_p
# Out:
#             20N_norm_scan75  20N_norm_scan76  20N_norm_scan77  \
# energy_cor
# 2460.3030         -0.011852        -0.011852        -0.012237
# 2460.4692         -0.016701        -0.016701        -0.016783
# 2460.6354         -0.013118        -0.013118        -0.011311
# 2460.8015         -0.015928        -0.015928        -0.013707
# 2460.9677         -0.014531        -0.014531        -0.018181
# 2461.1341         -0.016042        -0.016042        -0.013050
# 2461.3003         -0.009081        -0.009081        -0.015225
# 2461.4667         -0.009057        -0.009057        -0.006073
# 2461.6331         -0.013899        -0.013899        -0.010608
# 2461.7996         -0.014543        -0.014543        -0.011354
# 2461.9662         -0.001577        -0.001577        -0.011404
# 2462.1326         -0.010550        -0.010550        -0.010707
# 2462.2993         -0.013907        -0.013907        -0.008352
# 2462.4659         -0.003446        -0.003446        -0.007517
# ...

# %%
energy = all_data_p.index
energy
# Out:
# Float64Index([ 2460.303, 2460.4692, 2460.6354, 2460.8015, 2460.9677, 2461.1341,
#               2461.3003, 2461.4667, 2461.6331, 2461.7996,
#               ...
#               2528.4602,  2528.644, 2528.8278, 2529.0117, 2529.1955, 2529.3795,
#               2529.5636, 2529.7477, 2529.9317, 2530.1158],
#              dtype='float64', name='energy_cor', length=400)

# %%
##waterwall plotting
plt.figure(figsize=(16,16))

offset = 0 #giving offset a start value
n = all_data_p.shape[1] #number of columns in dataframe is the number of colors needed
color = iter(cm.seismic_r(np.linspace(0.6,1,n))) #assigning the colormap type to be iterated over the number of columns
    #cm... is the name of the colormap; put '_r' after this reverses the order
    #linspace(X,Y,n), the X,X is range of colors through which your n plots will step through
        #colormaps I like: seismic, jet, CMRmap, ocean, terrain, gist_earth, gnuplot2, winter
        #see: https://matplotlib.org/examples/color/colormaps_reference.html
    
#waterfall maker
for name in all_data_p:
    offset = offset+0.35   ##CHOOSE Y OFFSET HERE
    c = next(color)
    #plt.scatter(all_data.index, all_data[name]+offset, marker='.', s=18, label=name, c = c)
    plt.plot(energy, all_data_p[name]+offset, c = c, linewidth = 3)
    
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.title('XANES')
plt.ylabel('offset normalized intensity, AU')
plt.xlabel('energy, eV')
plt.xlim(2465,2515)   #not needed if subsample data above
plt.ylim(0,10)
xticks(np.arange(2465,2515.001, step=5))

axvline(2469.0, linewidth = 2, linestyle = ':', color = 'k')
axvline(2471.2, linewidth = 2, linestyle = ':', color = 'k')
axvline(2472.5, linewidth = 2, linestyle = ':', color = 'k')
axvline(2473.8, linewidth = 2, linestyle = ':', color = 'k')
axvline(2482.2, linewidth = 2, linestyle = ':', color = 'k')


##saving figure as a tif with index so can change formatting of colors etc without overwriting
savefmt = os.path.join('Figure_SI3',
                       '{}{{:d}}.{{}}'.format(FIG_name))
i = 1
while os.path.exists(savefmt.format(i,'tif')):
    i += 1
plt.savefig(savefmt.format(i,'tif'), bbox_inches = 'tight')
plt.savefig(savefmt.format(i,'pdf'), bbox_inches = 'tight')
plt.savefig(savefmt.format(i,'svg'), bbox_inches = 'tight')

#??#plt.ylim(0, [max(df[filename])+1000])    #how do I get this part to work??
plt.show()

# %%
##inset
figsize(8,8)
#ax1 = plt.plot(energy_2017, all_data_2017['020V.txt'],'b', linewidth = 3) #020V
ax2 = plt.plot(energy_2015, all_data_2015['020N.txt'],'b--', linewidth = 1.5) #020N

#ax3 = plt.plot(energy_2017, all_data_2017['415V.txt'],'r', linewidth = 3) #415V
ax4 = plt.plot(energy_2015, all_data_2015['415N.txt'],'r--', linewidth = 1.5) #415N

#ax5 = plt.plot(energy_2017, all_data_2017['600V.txt']+1,'g', linewidth = 3) #600V
ax6 = plt.plot(energy_2015, all_data_2015['600N.txt'], 'g--', linewidth = 1.5) #600N

#ax7 = plt.plot(energy_2017, all_data_2017['750V.txt'],'y', linewidth = 3) #750V
ax8 = plt.plot(energy_2015, all_data_2015['750N.txt'],'k--', linewidth = 1.5) #750N

#ax9 = plt.plot(energy_2017, all_data_2017['020VoilL4.txt'],'k-.', linewidth = 3) #020Voil
#ax10 = plt.plot(energy_2017, all_data_2017['750VoilL4.txt'],'k-.', linewidth = 3) #750Voil

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('offset normalized intensity, AU')
plt.xlabel('energy, eV')
plt.xlim(2465,2480)   #not needed if subsample data above
plt.ylim(0,1.5)
xticks(np.arange(2465,2480.001, step=5))

axvline(2469.0, linewidth = 2, linestyle = ':', color = 'k')
axvline(2471.2, linewidth = 2, linestyle = ':', color = 'k')
axvline(2472.5, linewidth = 2, linestyle = ':', color = 'k')
axvline(2473.8, linewidth = 2, linestyle = ':', color = 'k')


##saving figure as a tif with index so can change formatting of colors etc without overwriting
savefmt = os.path.join('Figure_SI3',
                       '{}{{:d}}.{{}}'.format(FIG_name))
i = 1
while os.path.exists(savefmt.format(i,'tif')):
    i += 1
plt.savefig(savefmt.format(i,'tif'), bbox_inches = 'tight')
plt.savefig(savefmt.format(i,'pdf'), bbox_inches = 'tight')
plt.savefig(savefmt.format(i,'svg'), bbox_inches = 'tight')

# %%
##standards for publication figures

SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

s=100
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
##full figure (publication size)
figsize(3.2,4)
fig, ax = plt.subplots()
ax.plot(energy_2017, all_data_2017['020V.txt']+0.4,'b', linewidth = 1) #020V
ax.plot(energy_2015, all_data_2015['020N.txt']+0.7,'b:', linewidth = 1) #020N

ax.plot(energy_2017, all_data_2017['415V.txt']+1.1,'r', linewidth = 1) #415V
ax.plot(energy_2015, all_data_2015['415N.txt']+1.4,'r:', linewidth = 1) #415N

#ax.plot(energy_2017, all_data_2017['600V.txt']+1.8,'g', linewidth = 1) #600V
ax.plot(energy_2015, all_data_2015['600N.txt']+2.1, 'g:', linewidth = 1) #600N

ax.plot(energy_2017, all_data_2017['750V.txt']+2.5,'k', linewidth = 1) #750V
ax.plot(energy_2015, all_data_2015['750N.txt']+2.8,'k:', linewidth = 1) #750N

ax.plot(energy_2017, all_data_2017['020VoilL4.txt'],'b-.', linewidth = 1) #020Voil
ax.plot(energy_2017, all_data_2017['750VoilL4.txt']+3.2,'k-.', linewidth = 1) #750Voil

#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('offset normalized intensity, AU')
plt.xlabel('energy, eV')
plt.xlim(2465,2515)   #not needed if subsample data above
plt.ylim(0,8.5)
xticks(np.arange(2465,2515.001, step=10))
#ax.tick_params(width = 2)

axvline(2469.0, linewidth = 0.5, linestyle = '--', color = 'k')
axvline(2471.2, linewidth = 0.5, linestyle = '--', color = 'k')
axvline(2472.5, linewidth = 0.5, linestyle = '--', color = 'k')
axvline(2473.8, linewidth = 0.5, linestyle = '--', color = 'k')
axvline(2482.2, linewidth = 0.5, linestyle = '--', color = 'k')


##saving figure as a tif with index so can change formatting of colors etc without overwriting
savefmt = os.path.join('Figure_SI3',
                       '{}{{:d}}.{{}}'.format(FIG_name))
i = 1
while os.path.exists(savefmt.format(i,'tif')):
    i += 1
plt.savefig(savefmt.format(i,'tif'), bbox_inches = 'tight')
plt.savefig(savefmt.format(i,'pdf'), bbox_inches = 'tight')
plt.savefig(savefmt.format(i,'svg'), bbox_inches = 'tight')

# %%
figsize(1.5,1.5)
fig, ax = plt.subplots()
#ax1 = plt.plot(energy_2017, all_data_2017['020V.txt'],'b', linewidth = 3) #020V
ax2 = plt.plot(energy_2015, all_data_2015['020N.txt'],'b', linewidth = 0.5) #020N

#ax3 = plt.plot(energy_2017, all_data_2017['415V.txt'],'r', linewidth = 3) #415V
ax4 = plt.plot(energy_2015, all_data_2015['415N.txt'],'r', linewidth = 0.5) #415N

#ax5 = plt.plot(energy_2017, all_data_2017['600V.txt']+1,'g', linewidth = 3) #600V
ax6 = plt.plot(energy_2015, all_data_2015['600N.txt'], 'g', linewidth = 0.5) #600N

#ax7 = plt.plot(energy_2017, all_data_2017['750V.txt'],'y', linewidth = 3) #750V
ax8 = plt.plot(energy_2015, all_data_2015['750N.txt'],'k', linewidth = 0.5) #750N

#ax9 = plt.plot(energy_2017, all_data_2017['020VoilL4.txt'],'k-.', linewidth = 3) #020Voil
#ax10 = plt.plot(energy_2017, all_data_2017['750VoilL4.txt'],'k-.', linewidth = 3) #750Voil

#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('normalized intensity, AU')
plt.xlabel('energy, eV')
plt.xlim(2465,2480)   #not needed if subsample data above
plt.ylim(0,1.5)
xticks(np.arange(2465,2480.001, step=5))

axvline(2469.0, linewidth = 0.25, linestyle = '--', color = 'k')
axvline(2471.2, linewidth = 0.25, linestyle = '--', color = 'k')
axvline(2472.5, linewidth = 0.25, linestyle = '--', color = 'k')
axvline(2473.8, linewidth = 0.25, linestyle = '--', color = 'k')


##saving figure as a tif with index so can change formatting of colors etc without overwriting
savefmt = os.path.join('Figure_SI3',
                       '{}{}{{:d}}.{{}}'.format(FIG_name, '_inset_'))
i = 1
while os.path.exists(savefmt.format(i,'tif')):
    i += 1
plt.savefig(savefmt.format(i,'tif'), bbox_inches = 'tight')
plt.savefig(savefmt.format(i,'pdf'), bbox_inches = 'tight')
plt.savefig(savefmt.format(i,'svg'), bbox_inches = 'tight')

# %% [markdown]
# ### end
